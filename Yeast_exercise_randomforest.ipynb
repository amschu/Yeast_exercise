# %%
import pandas as pd

data = pd.read_csv("C:/Users/Ally/Downloads/YPS163_matrix_without_interacting_partners.txt", sep="\t")

data.head()
#data.tail()
# Out:
#        UID  YPS163_log2_FC_Generation_10_versus_Generation_0  geneLen  \
# 0  YAL001C                                          1.932041     3483
# 1  YAL002W                                          0.113111     3825
# 2  YAL003W                                         -1.642942      621
# 3  YAL005C                                         -3.172214     1929
# 4  YAL007C                                         -0.382860      648
#
#         GC  median_IUPRED  X5UTR_PARS_RNAstructure  CDS_PARS_RNAstructure  \
# 0  37.1232         0.2541                      NaN                    NaN
# 1  37.1765         0.0719                      NaN                    NaN
# 2  44.6055         0.3494                -0.715385               1.217176
# 3  44.0643         0.3807                 0.660469               1.003508
# 4  37.0370         0.0632                 0.536046               0.494137
#
#    X3UTR_PARS_RNAstructure  AA_A  AA_C  ...  \
# 0                      NaN    52     7  ...
# ...

# %%
print(data.index)

data.info()
# Out:
# RangeIndex(start=0, stop=4116, step=1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Columns: 178 entries, UID to YPS606__Average_log2_FC_versus_BY4743
# dtypes: float64(156), int64(21), object(1)
# memory usage: 5.6+ MB

# %%
#seeing all the columns not a trucated view
pd.set_option('display.max_columns', None)
data.head()
# Out:
#        UID  YPS163_log2_FC_Generation_10_versus_Generation_0  geneLen  \
# 0  YAL001C                                          1.932041     3483
# 1  YAL002W                                          0.113111     3825
# 2  YAL003W                                         -1.642942      621
# 3  YAL005C                                         -3.172214     1929
# 4  YAL007C                                         -0.382860      648
#
#         GC  median_IUPRED  X5UTR_PARS_RNAstructure  CDS_PARS_RNAstructure  \
# 0  37.1232         0.2541                      NaN                    NaN
# 1  37.1765         0.0719                      NaN                    NaN
# 2  44.6055         0.3494                -0.715385               1.217176
# 3  44.0643         0.3807                 0.660469               1.003508
# 4  37.0370         0.0632                 0.536046               0.494137
#
#    X3UTR_PARS_RNAstructure  AA_A  AA_C  AA_D  AA_E  AA_F  AA_G  AA_H  AA_I  \
# ...

# %%
# Import train_test_split function

import sklearn

from sklearn.model_selection import train_test_split

import numpy as np
from numpy import nan #drop rows with missing values
data.dropna(inplace=True)

X=data[['YPS163_log2_FC_Generation_10_versus_Generation_0', 'geneLen', 'GC', 'median_IUPRED', 'X5UTR_PARS_RNAstructure', 'CDS_PARS_RNAstructure', 'X3UTR_PARS_RNAstructure', 'AA_A', 'AA_C', 'AA_D', 'AA_E', 'AA_F', 'AA_G', 'AA_H', 'AA_I', 'AA_K', 'AA_L', 'AA_M', 'AA_N', 'AA_P', 'AA_Q', 'AA_R', 'AA_S',
        'AA_T', 'AA_V', 'AA_W', 'AA_Y', 'X.AA_A', 'X.AA_C', 'X.AA_D', 'X.AA_E', 'X.AA_F', 'X.AA_G', 'X.AA_H', 'X.AA_I', 'X.AA_K', 'X.AA_L', 'X.AA_M', 'X.AA_N', 'X.AA_P', 'X.AA_Q', 'X.AA_R', 'X.AA_S', 'X.AA_T',
        'X.AA_V', 'X.AA_W', 'X.AA_Y', 'X.Helical', 'X.Proteinturn', 'X.Beta.sheet', 'BC187.Num_SNPs', 'BC187.Percent_SNPs', 'BC187.Num_AAChanges', 'BC187.Percent_AAChanges', 'BC187.SNP.HIGH', 'BC187.SNP.MODERATE', 'BC187.SNP.LOW', 'DBVPG1373.Num_SNPs', 'DBVPG1373.Percent_SNPs', 'DBVPG1373.Num_AAChanges']]
       
    #didn't use all the features
    
    #DBVPG1373.Percent_AAChanges	DBVPG1373.SNP.HIGH	DBVPG1373.SNP.MODERATE	DBVPG1373.SNP.LOW	NCYC3290.Num_SNPs	NCYC3290.Percent_SNPs	NCYC3290.Num_AAChanges	NCYC3290.Percent_AAChanges	NCYC3290.SNP.HIGH	NCYC3290.SNP.MODERATE	NCYC3290.SNP.LOW	Y12.Num_SNPs	Y12.Percent_SNPs	Y12.Num_AAChanges	Y12.Percent_AAChanges	Y12.SNP.HIGH	Y12.SNP.MODERATE	Y12.SNP.LOW	Y2209.Num_SNPs	Y2209.Percent_SNPs	Y2209.Num_AAChanges	Y2209.Percent_AAChanges	Y2209.SNP.HIGH	Y2209.SNP.MODERATE	Y2209.SNP.LOW	Y389.Num_SNPs	Y389.Percent_SNPs	Y389.Num_AAChanges	Y389.Percent_AAChanges	Y389.SNP.HIGH	Y389.SNP.MODERATE	Y389.SNP.LOW	Y7568.Num_SNPs	Y7568.Percent_SNPs	Y7568.Num_AAChanges	Y7568.Percent_AAChanges	Y7568.SNP.HIGH	Y7568.SNP.MODERATE	Y7568.SNP.LOW	YJM1273.Num_SNPs	YJM1273.Percent_SNPs	YJM1273.Num_AAChanges	YJM1273.Percent_AAChanges	YJM1273.SNP.HIGH	YJM1273.SNP.MODERATE	YJM1273.SNP.LOW	YJM1389.Num_SNPs	YJM1389.Percent_SNPs	YJM1389.Num_AAChanges	YJM1389.Percent_AAChanges	YJM1389.SNP.HIGH	YJM1389.SNP.MODERATE	YJM1389.SNP.LOW	YJM1592.Num_SNPs	YJM1592.Percent_SNPs	YJM1592.Num_AAChanges	YJM1592.Percent_AAChanges	YJM1592.SNP.HIGH	YJM1592.SNP.MODERATE	YJM1592.SNP.LOW	YJM978.Num_SNPs	YJM978.Percent_SNPs	YJM978.Num_AAChanges	YJM978.Percent_AAChanges	YJM978.SNP.HIGH	YJM978.SNP.MODERATE	YJM978.SNP.LOW	YPS128.Num_SNPs	YPS128.Percent_SNPs	YPS128.Num_AAChanges	YPS128.Percent_AAChanges	YPS128.SNP.HIGH	YPS128.SNP.MODERATE	YPS128.SNP.LOW	YPS163.Num_SNPs	YPS163.Percent_SNPs	YPS163.Num_AAChanges	YPS163.Percent_AAChanges	YPS163.SNP.HIGH	YPS163.SNP.MODERATE	YPS163.SNP.LOW	YPS606.Num_SNPs	YPS606.Percent_SNPs	YPS606.Num_AAChanges	YPS606.Percent_AAChanges	YPS606.SNP.HIGH	YPS606.SNP.MODERATE	YPS606.SNP.LOW	BY4743_Average_RPKM	BC187_Average_RPKM	DBVPG1373_Average_RPKM	NCYC3290_Average_RPKM	Y12_Average_RPKM	Y389_Average_RPKM	Y2209_Average_RPKM	Y7568_Average_RPKM	YJM978_Average_RPKM	YJM1273_Average_RPKM	YJM1389_Average_RPKM	YJM1592_Average_RPKM	YPS128_Average_RPKM	YPS163_Average_RPKM	YPS606_Average_RPKM	BC187_Average_log2_FC_versus_BY4743	DBVPG1373_Average_log2_FC_versus_BY4743	NCYC3290_Average_log2_FC_versus_BY4743	Y12_Average_log2_FC_versus_BY4743	Y389_Average_log2_FC_versus_BY4743	Y2209_Average_log2_FC_versus_BY4743	Y7568_Average_log2_FC_versus_BY4743	YJM978_Average_log2_FC_versus_BY4743	YJM1273_Average_log2_FC_versus_BY4743	YJM1389_Average_log2_FC_versus_BY4743	YJM1592_Average_log2_FC_versus_BY4743	'YPS128_Average_log2_FC_versus_BY4743', 'YPS163_Average_log2_FC_versus_BY4743', 'YPS606__Average_log2_FC_versus_BY4743']]
    
y=data['UID']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=None) #defualt none

# %%
from sklearn.ensemble import RandomForestClassifier

clf=RandomForestClassifier(n_estimators=100)

clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 690 entries, 3057 to 3251
# Data columns (total 60 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   YPS163_log2_FC_Generation_10_versus_Generation_0  690 non-null    float64
#  1   geneLen                                           690 non-null    int64
#  2   GC                                                690 non-null    float64
#  3   median_IUPRED                                     690 non-null    float64
#  4   X5UTR_PARS_RNAstructure                           690 non-null    float64
#  5   CDS_PARS_RNAstructure                             690 non-null    float64
#  6   X3UTR_PARS_RNAstructure                           690 non-null    float64
#  7   AA_A                                              690 non-null    int64
#  8   AA_C                                              690 non-null    int64
# ...

# %%
import scipy
from scipy import stats

pearson_coef = stats.pearsonr(X_test, y_test)

print("Pearson Correlation Coefficient: ", pearson_coef)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-81-4584d7887c80> in <module>
#       2 from scipy import stats
#       3
# ----> 4 pearson_coef = stats.pearsonr(X_test, y_test)
#       5
#       6 print("Pearson Correlation Coefficient: ", pearson_coef)
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3512     # that the data type is at least 64 bit floating point.  It might have
#    3513     # more precision if the input is, for example, np.longdouble.
# -> 3514     dtype = type(1.0 + x[0] + y[0])
#    3515
#    3516     if n == 2:
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')
